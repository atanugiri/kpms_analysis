# %%
from pathlib import Path

import keypoint_moseq as kpms

WORKDIR = Path.cwd().parent
dlc_project_dir = WORKDIR.parent / "dlc-pose-estimation" / "ElevatedMazeFood-Atanu-2026-04-04"
project_dir = WORKDIR / "results" / "ElevatedMazeFood"
config = kpms.load_config(str(project_dir))
model_name = project_dir / "multi_fit_20260708-13"

# load data (e.g. from DeepLabCut)
keypoint_data_path = str(dlc_project_dir / "raw_pose_data")  # can be a file, a directory, or a list of files
coordinates, confidences, bodyparts = kpms.load_keypoints(keypoint_data_path, "deeplabcut")
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Loading keypoints: 100%|████████████████| 23/23 [00:00<00:00, 93.33it/s]

# %%
results = kpms.load_results(str(project_dir), str(model_name))
kpms.generate_trajectory_plots(coordinates, results, str(project_dir), str(model_name), **config)
# Out:
# Saving trajectory plots to /Users/atanugiri/Downloads/kpms_analysis_2/results/ElevatedMazeFood/multi_fit_20260708-13/trajectory_plots
# Generating trajectory plots: 100%|██████| 28/28 [00:04<00:00,  5.76it/s]

# %%
kpms.generate_grid_movies(results, str(project_dir), str(model_name), coordinates=coordinates, **config);
# Out:
# Writing grid movies to /Users/atanugiri/Downloads/kpms_analysis_2/results/ElevatedMazeFood/multi_fit_20260708-13/grid_movies
# Using window size of 144 pixels
# Generating grid movies: 100%|███████████| 31/31 [01:43<00:00,  3.35s/it]os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.

# %%
kpms.plot_similarity_dendrogram(coordinates, results, str(project_dir), str(model_name), **config)
# Out:
# Saving dendrogram plot to /Users/atanugiri/Downloads/kpms_analysis_2/results/ElevatedMazeFood/multi_fit_20260708-13/similarity_dendrogram
